# %% [markdown]
# # DriftGuard-GNN — Quick PoC Run
# SE4012 | IT23223394
#
# **Steps:**
# 1. Upload Elliptic CSVs to `data/` (or mount Google Drive)
# 2. Install dependencies
# 3. Load data, build strict-inductive splits
# 4. Train RF, Standard GCN, Neighbour-Aware GCN
# 5. Compare low-drift vs high-drift performance

# %%
# !pip install torch-geometric -q
# !git clone https://github.com/YOUR_USERNAME/DriftGuard-GNN-PoC.git
# %cd DriftGuard-GNN-PoC

# %%
# Download Elliptic dataset from Kaggle into data/ before running this cell
import sys
sys.path.append('src')
from data_loader import load_elliptic, build_strict_inductive_splits

merged, edges = load_elliptic('data')
train_df, test_df, train_edges = build_strict_inductive_splits(merged, edges)

# %%
# TODO next session: convert train_df/test_df into PyG Data objects,
# split test_df further into low-drift (34-40) vs high-drift (41-49)
# sub-windows for a finer comparison, train all 3 models, run evaluate.py
